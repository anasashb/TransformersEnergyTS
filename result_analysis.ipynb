# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
import pandas as pd

# %%
# MSE function 
def MSE(pred, true):
    return np.mean((pred-true)**2)

# %% [markdown]
# ### Synthetic Data

# %%
# Load Informer Results for 24-Hour Synthetic Data
informer_synthpreds_24 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthtrue_24 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmetrics_24 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 24-Hour Synthetic Data
                                                       
autoformer_synthpreds_24 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthtrue_24 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmetrics_24 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 24-Hour Synthetic Data
pyraformer_synthpreds_24 = np.load('results/results_new/PyraformerSYNTHh1124FC/pred.npy')
pyraformer_synthtrue_24 = np.load('results/results_new/PyraformerSYNTHh1124FC/true.npy')
#pyraformer_synthmetrics_24 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic24.npy')

# Load Crossformer Results for 24-Hour Synthetic Data
                                                        
crossformer_synthpreds_24 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthtrue_24 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmetrics_24 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 24-Hour Synthetic Data
fedformer_synthpreds_24 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthtrue_24 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmetrics_24 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 48-Hour Synthetic Data
informer_synthpreds_48 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthtrue_48 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmetrics_48 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 48-Hour Synthetic Data
autoformer_synthpreds_48 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthtrue_48 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmetrics_48 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 48-Hour Synthetic Data
pyraformer_synthpreds_48 = np.load('results/results_new/PyraformerSYNTHh1148FC/pred.npy')
pyraformer_synthtrue_48 = np.load('results/results_new/PyraformerSYNTHh1148FC/true.npy')
#pyraformer_synthmetrics_24 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic24.npy')

# Load Crossformer Results for 48-Hour Synthetic Data
crossformer_synthpreds_48 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthtrue_48 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmetrics_48 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 48-Hour Synthetic Data
fedformer_synthpreds_48 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthtrue_48 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmetrics_48 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 168-Hour Synthetic Data
informer_synthpreds_168 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthtrue_168 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmetrics_168 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 168-Hour Synthetic Data
autoformer_synthpreds_168 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthtrue_168 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmetrics_168 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 168-Hour Synthetic Data
pyraformer_synthpreds_168 = np.load('results/results_new/PyraformerSYNTHh11168FC/pred.npy')
pyraformer_synthtrue_168 = np.load('results/results_new/PyraformerSYNTHh11168FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 168-Hour Synthetic Data
crossformer_synthpreds_168 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthtrue_168 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmetrics_168 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 168-Hour Synthetic Data
fedformer_synthpreds_168 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthtrue_168 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmetrics_168 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 336-Hour Synthetic Data
informer_synthpreds_336 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthtrue_336 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmetrics_336 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 336-Hour Synthetic Data
autoformer_synthpreds_336 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthtrue_336 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmetrics_336 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 336-Hour Synthetic Data
pyraformer_synthpreds_336 = np.load('results/results_new/PyraformerSYNTHh11336FC/pred.npy')
pyraformer_synthtrue_336 = np.load('results/results_new/PyraformerSYNTHh11336FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 336-Hour Synthetic Data
crossformer_synthpreds_336 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthtrue_336 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmetrics_336 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 336-Hour Synthetic Data
fedformer_synthpreds_336 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthtrue_336 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmetrics_336 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 720-Hour Synthetic Data
informer_synthpreds_720 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthtrue_720 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmetrics_720 = np.load('results/results_new/informerstack_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 720-Hour Synthetic Data
autoformer_synthpreds_720 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthtrue_720 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmetrics_720 = np.load('results/results_new/Autoformer_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 720-Hour Synthetic Data
pyraformer_synthpreds_720 = np.load('results/results_new/PyraformerSYNTHh11720FC/pred.npy')
pyraformer_synthtrue_720 = np.load('results/results_new/PyraformerSYNTHh11720FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 720-Hour Synthetic Data
crossformer_synthpreds_720 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthtrue_720 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmetrics_720 = np.load('results/results_new/Crossformer_SYNTHh1_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 720-Hour Synthetic Data
fedformer_synthpreds_720 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthtrue_720 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmetrics_720 = np.load('results/results_new/Fedformer_SYNTHh1_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# %%
mse_pyrasynth_24 = np.array([MSE(pyraformer_synthtrue_24[i, :, :], pyraformer_synthpreds_24 [i, :, :]) for i in range(len(pyraformer_synthpreds_24))])
mse_pyrasynth_48 = np.array([MSE(pyraformer_synthtrue_48[i, :, :], pyraformer_synthpreds_48 [i, :, :]) for i in range(len(pyraformer_synthpreds_48))])
mse_pyrasynth_168 = np.array([MSE(pyraformer_synthtrue_168[i, :, :], pyraformer_synthpreds_168 [i, :, :]) for i in range(len(pyraformer_synthpreds_168))])
mse_pyrasynth_336 = np.array([MSE(pyraformer_synthtrue_336[i, :, :], pyraformer_synthpreds_336 [i, :, :]) for i in range(len(pyraformer_synthpreds_336))])
mse_pyrasynth_720 = np.array([MSE(pyraformer_synthtrue_720[i, :, :], pyraformer_synthpreds_720 [i, :, :]) for i in range(len(pyraformer_synthpreds_720))])

# %%
mse_synth_informer = [informer_synthmetrics_24[1], informer_synthmetrics_48[1], informer_synthmetrics_168[1], informer_synthmetrics_336[1], informer_synthmetrics_720[1]]
mse_synth_autoformer = [autoformer_synthmetrics_24[1], autoformer_synthmetrics_48[1], autoformer_synthmetrics_168[1], autoformer_synthmetrics_336[1], autoformer_synthmetrics_720[1]]
mse_synth_crossformer = [crossformer_synthmetrics_24[1], crossformer_synthmetrics_48[1], crossformer_synthmetrics_168[1], crossformer_synthmetrics_336[1], crossformer_synthmetrics_720[1]]
mse_synth_fedformer = [fedformer_synthmetrics_24[1], fedformer_synthmetrics_48[1], fedformer_synthmetrics_168[1], fedformer_synthmetrics_336[1], fedformer_synthmetrics_720[1]]
mse_synth_pyraformer = [np.mean(mse_pyrasynth_24), np.mean(mse_pyrasynth_48), np.mean(mse_pyrasynth_168), np.mean(mse_pyrasynth_336), np.mean(mse_pyrasynth_720)]

# %%
windows = [24, 48, 168, 336, 720]
plt.figure(figsize=(12, 6))
plt.plot(windows, mse_synth_informer, marker='o', label='Informer')
plt.plot(windows, mse_synth_autoformer, marker='s', label='Autoformer')
plt.plot(windows, mse_synth_crossformer , marker='^', label='Crossformer')
plt.plot(windows, mse_synth_fedformer, marker='*', label='Fedformer')
plt.plot(windows, mse_synth_pyraformer, marker='x', label='Pyraformer')
plt.xlabel('Prediction Windows')
plt.xticks(windows)
plt.ylabel('MSE')
plt.title('Models Performances on Synthetic Data')
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Synthetic Data - Additive

# %%
# Load Informer Results for 24-Hour Synthetic Additive Data
                                                     
informer_synthaddpreds_24 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddtrue_24 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddmetrics_24 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 24-Hour Synthetic Additive Data
                                                       
autoformer_synthaddpreds_24 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddtrue_24 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddmetrics_24 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 24-Hour Synthetic Additive Data
pyraformer_synthaddpreds_24 = np.load('results/results_new/PyraformerSYNTH_additive124FC/pred.npy')
pyraformer_synthaddtrue_24 = np.load('results/results_new/PyraformerSYNTH_additive124FC/true.npy')
#pyraformer_synthmetrics_24 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic24.npy')

# Load Crossformer Results for 24-Hour Synthetic Additive Data
                                                        
crossformer_synthaddpreds_24 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthaddtrue_24 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddmetrics_24 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 24-Hour Synthetic Additive Data
fedformer_synthaddpreds_24 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddtrue_24 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddmetrics_24 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 48-Hour Synthetic Additive Data
informer_synthaddpreds_48 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddtrue_48 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddmetrics_48 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 48-Hour Synthetic Additive Data
autoformer_synthaddpreds_48 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddtrue_48 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddmetrics_48 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 48-Hour Synthetic Additive Data
pyraformer_synthaddpreds_48 = np.load('results/results_new/PyraformerSYNTH_additive148FC/pred.npy')
pyraformer_synthaddtrue_48 = np.load('results/results_new/PyraformerSYNTH_additive148FC/true.npy')
#pyraformer_synthmetrics_24 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic24.npy')

# Load Crossformer Results for 48-Hour Synthetic Additive Data
crossformer_synthaddpreds_48 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthaddtrue_48 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddmetrics_48 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 48-Hour Synthetic Additive Data
fedformer_synthaddpreds_48 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddtrue_48 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddmetrics_48 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 168-Hour Synthetic Additive Data
informer_synthaddpreds_168 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddtrue_168 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddmetrics_168 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 168-Hour Synthetic Additive Data
autoformer_synthaddpreds_168 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddtrue_168 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddmetrics_168 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 168-Hour Synthetic Additive Data
pyraformer_synthaddpreds_168 = np.load('results/results_new/PyraformerSYNTH_additive1168FC/pred.npy')
pyraformer_synthaddtrue_168 = np.load('results/results_new/PyraformerSYNTH_additive1168FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 168-Hour Synthetic Additive Data
crossformer_synthaddpreds_168 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthaddtrue_168 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddmetrics_168 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 168-Hour Synthetic Additive Data
fedformer_synthaddpreds_168 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddtrue_168 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddmetrics_168 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 336-Hour Synthetic Additive Data
informer_synthaddpreds_336 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddtrue_336 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddmetrics_336 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 336-Hour Synthetic Additive Data
autoformer_synthaddpreds_336 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddtrue_336 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddmetrics_336 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 336-Hour Synthetic Additive Data
pyraformer_synthaddpreds_336 = np.load('results/results_new/PyraformerSYNTH_additive1336FC/pred.npy')
pyraformer_synthaddtrue_336 = np.load('results/results_new/PyraformerSYNTH_additive1336FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 336-Hour Synthetic Additive Data
crossformer_synthaddpreds_336 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthaddtrue_336 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddmetrics_336 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 336-Hour Synthetic Additive Data
fedformer_synthaddpreds_336 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddtrue_336 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddmetrics_336 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 720-Hour Synthetic Additive Data
informer_synthaddpreds_720 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddtrue_720 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddmetrics_720 = np.load('results/results_new/informerstack_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 720-Hour Synthetic Additive Data
autoformer_synthaddpreds_720 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddtrue_720 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddmetrics_720 = np.load('results/results_new/Autoformer_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 720-Hour Synthetic Additive Data
pyraformer_synthaddpreds_720 = np.load('results/results_new/PyraformerSYNTH_additive1720FC/pred.npy')
pyraformer_synthaddtrue_720 = np.load('results/results_new/PyraformerSYNTH_additive1720FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 720-Hour Synthetic Additive Data
crossformer_synthaddpreds_720 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthaddtrue_720 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddmetrics_720 = np.load('results/results_new/Crossformer_SYNTH_additive_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 720-Hour Synthetic Additive Data
fedformer_synthaddpreds_720 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddtrue_720 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddmetrics_720 = np.load('results/results_new/Fedformer_SYNTH_additive_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# %%
mse_pyrasynthadd_24 = np.array([MSE(pyraformer_synthaddtrue_24[i, :, :], pyraformer_synthaddpreds_24 [i, :, :]) for i in range(len(pyraformer_synthaddpreds_24))])
mse_pyrasynthadd_48 = np.array([MSE(pyraformer_synthaddtrue_48[i, :, :], pyraformer_synthaddpreds_48 [i, :, :]) for i in range(len(pyraformer_synthaddpreds_48))])
mse_pyrasynthadd_168 = np.array([MSE(pyraformer_synthaddtrue_168[i, :, :], pyraformer_synthaddpreds_168 [i, :, :]) for i in range(len(pyraformer_synthaddpreds_168))])
mse_pyrasynthadd_336 = np.array([MSE(pyraformer_synthaddtrue_336[i, :, :], pyraformer_synthaddpreds_336 [i, :, :]) for i in range(len(pyraformer_synthaddpreds_336))])
mse_pyrasynthadd_720 = np.array([MSE(pyraformer_synthaddtrue_720[i, :, :], pyraformer_synthaddpreds_720 [i, :, :]) for i in range(len(pyraformer_synthaddpreds_720))])

# %%
mse_synthadd_informer = [informer_synthaddmetrics_24[1], informer_synthaddmetrics_48[1], informer_synthaddmetrics_168[1], informer_synthaddmetrics_336[1], informer_synthaddmetrics_720[1]]
mse_synthadd_autoformer = [autoformer_synthaddmetrics_24[1], autoformer_synthaddmetrics_48[1], autoformer_synthaddmetrics_168[1], autoformer_synthaddmetrics_336[1], autoformer_synthaddmetrics_720[1]]
mse_synthadd_crossformer = [crossformer_synthaddmetrics_24[1], crossformer_synthaddmetrics_48[1], crossformer_synthaddmetrics_168[1], crossformer_synthaddmetrics_336[1], crossformer_synthaddmetrics_720[1]]
mse_synthadd_fedformer = [fedformer_synthaddmetrics_24[1], fedformer_synthaddmetrics_48[1], fedformer_synthaddmetrics_168[1], fedformer_synthaddmetrics_336[1], fedformer_synthaddmetrics_720[1]]
mse_synthadd_pyraformer = [np.mean(mse_pyrasynthadd_24), np.mean(mse_pyrasynthadd_48), np.mean(mse_pyrasynthadd_168), np.mean(mse_pyrasynthadd_336), np.mean(mse_pyrasynthadd_720)]

# %%
windows = [24, 48, 168, 336, 720]
plt.figure(figsize=(12, 6))
plt.plot(windows, mse_synthadd_informer, marker='o', label='Informer')
plt.plot(windows, mse_synthadd_autoformer, marker='s', label='Autoformer')
plt.plot(windows, mse_synthadd_crossformer , marker='^', label='Crossformer')
plt.plot(windows, mse_synthadd_fedformer, marker='*', label='Fedformer')
plt.plot(windows, mse_synthadd_pyraformer, marker='x', label='Pyraformer')
plt.xlabel('Prediction Windows')
plt.ylabel('MSE')
plt.xticks(windows)
plt.title('Models Performances on Synthetic Data with Additive Trend')
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Synthetic Data - Additive with Reversals

# %%
# Load Informer Results for 24-Hour Synthetic Additive with Reversals Data 
                                                     
informer_synthaddreversalspreds_24 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddreversalstrue_24 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddreversalsmetrics_24 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 24-Hour Synthetic Additive with Reversals Data
                                                       
autoformer_synthaddreversalspreds_24 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddreversalstrue_24 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddreversalsmetrics_24 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 24-Hour Synthetic Additive with Reversals Data
pyraformer_synthaddreversalspreds_24 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_24/preds.npy')
pyraformer_synthaddreversalstrue_24 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_24/trues.npy')


# Load Crossformer Results for 24-Hour Synthetic Additive with Reversals Data
                                                        
#crossformer_synthadreversalsdpreds_24 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl24_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
#crossformer_synthaddreversalstrue_24 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl24_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddreversalsmetrics_24 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl24_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 24-Hour Synthetic Additive with Reversals Data
fedformer_synthaddreversalspreds_24 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddreversalstrue_24 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddreversalsmetrics_24 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 48-Hour Synthetic Additive with Reversals Data
informer_synthaddreversalspreds_48 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddreversalstrue_48 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddreversalsmetrics_48 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 48-Hour Synthetic Additive with Reversals Data
autoformer_synthaddreversalspreds_48 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddreversalstrue_48 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddreversalsmetrics_48 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 48-Hour Synthetic Additive with Reversals Data
pyraformer_synthaddreversalspreds_48 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_48/preds.npy')
pyraformer_synthaddreversalstrue_48  = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_48/trues.npy')


# Load Crossformer Results for 48-Hour Synthetic Additive with Reversals Data
#crossformer_synthaddreversalspreds_48 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl48_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
#crossformer_synthaddreversalstrue_48 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl48_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddreversalsmetrics_48 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl48_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 48-Hour Synthetic Additive with Reversals Data
fedformer_synthaddreversalspreds_48 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddreversalstrue_48 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddreversalsmetrics_48 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 168-Hour Synthetic Additive with Reversals Data
informer_synthaddreversalspreds_168 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddreversalstrue_168 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddreversalsmetrics_168 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 168-Hour Synthetic Additive with Reversals Data
autoformer_synthaddreversalspreds_168 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddreversalstrue_168 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddreversalsmetrics_168 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 168-Hour Synthetic Additive with Reversals Data
pyraformer_synthaddreversalspreds_168 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_168/preds.npy')
pyraformer_synthaddreversalstrue_168 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_168/trues.npy')


# Load Crossformer Results for 168-Hour Synthetic Additive with Reversals Data
#crossformer_synthaddpreds_168 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl168_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
#crossformer_synthaddtrue_168 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl168_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddreversalsmetrics_168 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl168_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 168-Hour Synthetic Additive with Reversals Data
fedformer_synthaddreversalspreds_168 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddreversalstrue_168 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddreversalsmetrics_168 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 336-Hour Synthetic Additive with Reversals Data
informer_synthaddreversalspreds_336 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddreversalstrue_336 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddreversalsmetrics_336 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 336-Hour Synthetic Additive with Reversals Data
autoformer_synthaddreversalspreds_336 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddreversalstrue_336 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddreversalsmetrics_336 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 336-Hour Synthetic Additive with Reversals Data
pyraformer_synthaddreversalspreds_336 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_336/preds.npy')
pyraformer_synthaddreversalstrue_336 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_336/trues.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 336-Hour Synthetic Additive with Reversals Data
#crossformer_synthaddreversalspreds_336 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl336_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
#crossformer_synthaddreversalstrue_336 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl336_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddreversalsmetrics_336 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl336_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 336-Hour Synthetic Additive with Reversals Data
fedformer_synthaddreversalspreds_336 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddreversalstrue_336 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddreversalsmetrics_336 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 720-Hour Synthetic Additive with Reversals Data
informer_synthaddreversalspreds_720 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthaddreversalstrue_720 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthaddreversalsmetrics_720 = np.load('results/results_new/informerstack_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 720-Hour Synthetic Additive with Reversals Data
autoformer_synthaddreversalspreds_720 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthaddreversalstrue_720 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthaddreversalsmetrics_720 = np.load('results/results_new/Autoformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 720-Hour Synthetic Additive with Reversals Data
pyraformer_synthaddreversalspreds_720 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_720/preds.npy')
pyraformer_synthaddreversalstrue_720 = np.load('results/results_new/Pyraformer_SYNTH_additive_reversal_pred_len:_720/trues.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 720-Hour Synthetic Additive with Reversals Data
#crossformer_synthaddreversalspreds_720 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl720_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
#crossformer_synthaddreversalstrue_720 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl720_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthaddreversalsmetrics_720 = np.load('results/results_new/Crossformer_SYNTH_additive_reversal_il96_pl720_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 720-Hour Synthetic Additive with Reversals Data
fedformer_synthaddreversalspreds_720 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthaddreversalstrue_720 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthaddreversalsmetrics_720 = np.load('results/results_new/Fedformer_SYNTH_additive_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# %%
mse_pyrasynth_add_reversal_24 = np.array([MSE(pyraformer_synthaddreversalstrue_24[i, :, :], pyraformer_synthaddreversalspreds_24 [i, :, :]) for i in range(len(pyraformer_synthaddreversalstrue_24))])
mse_pyrasynth_add_reversal_48 = np.array([MSE(pyraformer_synthaddreversalstrue_48[i, :, :], pyraformer_synthaddreversalspreds_48 [i, :, :]) for i in range(len(pyraformer_synthaddreversalstrue_48))])
mse_pyrasynth_add_reversal_168 = np.array([MSE(pyraformer_synthaddreversalstrue_168[i, :, :], pyraformer_synthaddreversalspreds_168 [i, :, :]) for i in range(len(pyraformer_synthaddreversalstrue_168))])
mse_pyrasynth_add_reversal_336 = np.array([MSE(pyraformer_synthaddreversalstrue_336[i, :, :], pyraformer_synthaddreversalspreds_336 [i, :, :]) for i in range(len(pyraformer_synthaddreversalstrue_336))])
mse_pyrasynth_add_reversal_720 = np.array([MSE(pyraformer_synthaddreversalstrue_720[i, :, :], pyraformer_synthaddreversalspreds_720 [i, :, :]) for i in range(len(pyraformer_synthaddreversalstrue_720))])

# %%
mse_synthaddreversal_informer = [informer_synthaddreversalsmetrics_24[1], informer_synthaddreversalsmetrics_48[1], informer_synthaddreversalsmetrics_168[1], informer_synthaddreversalsmetrics_336[1], informer_synthaddreversalsmetrics_720[1]]
mse_synthaddreversal_autoformer = [autoformer_synthaddreversalsmetrics_24[1], autoformer_synthaddreversalsmetrics_48[1], autoformer_synthaddreversalsmetrics_168[1], autoformer_synthaddreversalsmetrics_336[1], autoformer_synthaddreversalsmetrics_720[1]]
mse_synthaddreversal_crossformer = [crossformer_synthaddreversalsmetrics_24[1], crossformer_synthaddreversalsmetrics_48[1], crossformer_synthaddreversalsmetrics_168[1], crossformer_synthaddreversalsmetrics_336[1], crossformer_synthaddreversalsmetrics_720[1]]
mse_synthaddreversal_fedformer = [fedformer_synthaddreversalsmetrics_24[1], fedformer_synthaddreversalsmetrics_48[1], fedformer_synthaddreversalsmetrics_168[1], fedformer_synthaddreversalsmetrics_336[1], fedformer_synthaddreversalsmetrics_720[1]]
mse_synthaddreversal_pyraformer = [np.mean(mse_pyrasynth_add_reversal_24), np.mean(mse_pyrasynth_add_reversal_48), np.mean(mse_pyrasynth_add_reversal_168), np.mean(mse_pyrasynth_add_reversal_336), np.mean(mse_pyrasynth_add_reversal_720)]

# %%
windows = [24, 48, 168, 336, 720]
plt.figure(figsize=(12, 6))
plt.plot(windows, mse_synthaddreversal_informer, marker='o', label='Informer')
plt.plot(windows, mse_synthaddreversal_autoformer, marker='s', label='Autoformer')
plt.plot(windows, mse_synthaddreversal_crossformer , marker='^', label='Crossformer')
plt.plot(windows, mse_synthaddreversal_fedformer, marker='*', label='Fedformer')
#plt.plot(windows, mse_synthaddreversal_pyraformer, marker='x', label='Pyraformer')
plt.xlabel('Prediction Windows')
plt.ylabel('MSE')
plt.xticks([24, 48, 168, 336, 720])
plt.title('Models Performances on Synthetic Data with Additive Trend and Reversals')
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Synthetic Data - Multiplicative

# %%
# Load Informer Results for 24-Hour Synthetic Multiplicative Data
                                                     
informer_synthmulpreds_24 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmultrue_24 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulmetrics_24 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 24-Hour Synthetic Multiplicative Data
                                                       
autoformer_synthmulpreds_24 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmultrue_24 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulmetrics_24 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 24-Hour Synthetic Multiplicative Data
pyraformer_synthmulpreds_24 = np.load('results/results_new/PyraformerSYNTH_multiplicative124FC/pred.npy')
pyraformer_synthmultrue_24 = np.load('results/results_new/PyraformerSYNTH_multiplicative124FC/true.npy')
#pyraformer_synthmetrics_24 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic24.npy')

# Load Crossformer Results for 24-Hour Synthetic Multiplicative Data
                                                        
crossformer_synthmulpreds_24 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmultrue_24 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulmetrics_24 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 24-Hour Synthetic Multiplicative Data
fedformer_synthmulpreds_24 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmultrue_24 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulmetrics_24 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 48-Hour Synthetic Multiplicative Data
informer_synthmulpreds_48 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmultrue_48 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulmetrics_48 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 48-Hour Synthetic Multiplicative Data
autoformer_synthmulpreds_48 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmultrue_48 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulmetrics_48 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 48-Hour Synthetic Multiplicative Data
pyraformer_synthmulpreds_48 = np.load('results/results_new/PyraformerSYNTH_multiplicative148FC/pred.npy')
pyraformer_synthmultrue_48 = np.load('results/results_new/PyraformerSYNTH_multiplicative148FC/true.npy')
#pyraformer_synthmetrics_24 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic24.npy')

# Load Crossformer Results for 48-Hour Synthetic Multiplicative Data
crossformer_synthmulpreds_48 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmultrue_48 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulmetrics_48 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 48-Hour Synthetic Multiplicative Data
fedformer_synthmulpreds_48 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmultrue_48 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulmetrics_48 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 168-Hour Synthetic Multiplicative Data
informer_synthmulpreds_168 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmultrue_168 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulmetrics_168 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 168-Hour Synthetic Multiplicative Data
autoformer_synthmulpreds_168 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmultrue_168 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulmetrics_168 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 168-Hour Synthetic Multiplicative Data
pyraformer_synthmulpreds_168 = np.load('results/results_new/PyraformerSYNTH_multiplicative1168FC/pred.npy')
pyraformer_synthmultrue_168 = np.load('results/results_new/PyraformerSYNTH_multiplicative1168FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 168-Hour Synthetic Multiplicative Data
crossformer_synthmulpreds_168 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmultrue_168 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulmetrics_168 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 168-Hour Synthetic Multiplicative Data
fedformer_synthmulpreds_168 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmultrue_168 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulmetrics_168 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 336-Hour Synthetic Multiplicative Data
informer_synthmulpreds_336 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmultrue_336 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulmetrics_336 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 336-Hour Synthetic Multiplicative Data
autoformer_synthmulpreds_336 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmultrue_336 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulmetrics_336 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 336-Hour Synthetic Multiplicative Data
pyraformer_synthmulpreds_336 = np.load('results/results_new/PyraformerSYNTH_multiplicative1336FC/pred.npy')
pyraformer_synthmultrue_336 = np.load('results/results_new/PyraformerSYNTH_multiplicative1336FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')

# Load Crossformer Results for 336-Hour Synthetic Multiplicative Data
crossformer_synthmulpreds_336 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmultrue_336 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulmetrics_336 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 336-Hour Synthetic Multiplicative Data
fedformer_synthmulpreds_336 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmultrue_336 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulmetrics_336 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 720-Hour Synthetic Multiplicative Data
informer_synthmulpreds_720 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmultrue_720 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulmetrics_720 = np.load('results/results_new/informerstack_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 720-Hour Synthetic Multiplicative Data
autoformer_synthmulpreds_720 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmultrue_720 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulmetrics_720 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 720-Hour Synthetic Multiplicative Data
pyraformer_synthmulpreds_720 = np.load('results/results_new/PyraformerSYNTH_multiplicative1720FC/pred.npy')
pyraformer_synthmultrue_720 = np.load('results/results_new/PyraformerSYNTH_multiplicative1720FC/true.npy')
#pyraformer_synthmetrics_168 = np.load('Pyraformer/results_new/results/syntheticmetricssynthetic168.npy')


# Load Crossformer Results for 720-Hour Synthetic Multiplicative Data
crossformer_synthmulpreds_720 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmultrue_720 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulmetrics_720 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 720-Hour Synthetic Multiplicative Data
fedformer_synthmulpreds_720 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmultrue_720 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulmetrics_720 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# %%
mse_pyrasynthmul_24 = np.array([MSE(pyraformer_synthmultrue_24[i, :, :], pyraformer_synthmulpreds_24 [i, :, :]) for i in range(len(pyraformer_synthmulpreds_24))])
mse_pyrasynthmul_48 = np.array([MSE(pyraformer_synthmultrue_48[i, :, :], pyraformer_synthmulpreds_48 [i, :, :]) for i in range(len(pyraformer_synthmulpreds_48))])
mse_pyrasynthmul_168 = np.array([MSE(pyraformer_synthmultrue_168[i, :, :], pyraformer_synthmulpreds_168 [i, :, :]) for i in range(len(pyraformer_synthmulpreds_168))])
mse_pyrasynthmul_336 = np.array([MSE(pyraformer_synthmultrue_336[i, :, :], pyraformer_synthmulpreds_336 [i, :, :]) for i in range(len(pyraformer_synthmulpreds_336))])
mse_pyrasynthmul_720 = np.array([MSE(pyraformer_synthmultrue_720[i, :, :], pyraformer_synthmulpreds_720 [i, :, :]) for i in range(len(pyraformer_synthmulpreds_720))])

# %%
mse_synthmul_informer = [informer_synthmulmetrics_24[1], informer_synthmulmetrics_48[1], informer_synthmulmetrics_168[1], informer_synthmulmetrics_336[1], informer_synthmulmetrics_720[1]]
mse_synthmul_autoformer = [autoformer_synthmulmetrics_24[1], autoformer_synthmulmetrics_48[1], autoformer_synthmulmetrics_168[1], autoformer_synthmulmetrics_336[1], autoformer_synthmulmetrics_720[1]]
mse_synthmul_crossformer = [crossformer_synthmulmetrics_24[1], crossformer_synthmulmetrics_48[1], crossformer_synthmulmetrics_168[1], crossformer_synthmulmetrics_336[1], crossformer_synthmulmetrics_720[1]]
mse_synthmul_fedformer = [fedformer_synthmulmetrics_24[1], fedformer_synthmulmetrics_48[1], fedformer_synthmulmetrics_168[1], fedformer_synthmulmetrics_336[1], fedformer_synthmulmetrics_720[1]]
mse_synthmul_pyraformer = [np.mean(mse_pyrasynthmul_24), np.mean(mse_pyrasynthmul_48), np.mean(mse_pyrasynthmul_168), np.mean(mse_pyrasynthmul_336), np.mean(mse_pyrasynthmul_720)]

# %%
windows = [24, 48, 168, 336, 720]
plt.figure(figsize=(12, 6))
plt.plot(windows, mse_synthmul_informer, marker='o', label='Informer')
plt.plot(windows, mse_synthmul_autoformer, marker='s', label='Autoformer')
plt.plot(windows, mse_synthmul_crossformer , marker='^', label='Crossformer')
plt.plot(windows, mse_synthmul_fedformer, marker='*', label='Fedformer')
plt.plot(windows, mse_synthmul_pyraformer, marker='x', label='Pyraformer')
plt.xlabel('Prediction Windows')
plt.ylabel('MSE')
plt.xticks(windows)
plt.title('Models Performances on Synthetic Data with Multiplicativetive Trend')
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Synthetic Data - Multiplicative with Reversals

# %%
# Load Informer Results for 24-Hour Synthetic Multiplicative Data with Reversals
                                                     
informer_synthmulreversalspreds_24 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmulreversalstrue_24 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulreversalsmetrics_24 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 24-Hour Synthetic Multiplicative Data with Reversals
                                                       
autoformer_synthmulreversalspreds_24 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmulreversalstrue_24 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulreversalsmetrics_24 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 24-Hour Synthetic Multiplicative Data with Reversals
pyraformer_synthmulreversalspreds_24 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_24/preds.npy')
pyraformer_synthmulreversalstrue_24 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_24/trues.npy')

# Load Crossformer Results for 24-Hour Synthetic Multiplicative Data with Reversals
                                                        
crossformer_synthmulreversalspreds_24 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl24_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmulreversalstrue_24 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl24_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulreversalsmetrics_24 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl24_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 24-Hour Synthetic Multiplicative Data with Reversals
fedformer_synthmulreversalspreds_24 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmulreversalstrue_24 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulreversalsmetrics_24 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 48-Hour Synthetic Multiplicative Data with Reversals
informer_synthmulreversalspreds_48 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmulreversalstrue_48 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulreversalsmetrics_48 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 48-Hour Synthetic Multiplicative Data with Reversals
autoformer_synthmulreversalspreds_48 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmulreversalstrue_48 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulreversalsmetrics_48 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 48-Hour Synthetic Multiplicative Data with Reversals
pyraformer_synthmulreversalspreds_48 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_48/preds.npy')
pyraformer_synthmulreversalstrue_48 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_48/trues.npy')


# Load Crossformer Results for 48-Hour Synthetic Multiplicative Data with Reversals
crossformer_synthmulreversalspreds_48 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl48_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmulreversalstrue_48 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl48_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulreversalsmetrics_48 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl48_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 48-Hour Synthetic Multiplicative Data with Reversals
fedformer_synthmulreversalspreds_48 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmulreversalstrue_48 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulreversalsmetrics_48 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 168-Hour Synthetic Multiplicative Data with Reversals
informer_synthmulreversalspreds_168 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmulreversalstrue_168 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulreversalsmetrics_168 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 168-Hour Synthetic Multiplicative Data with Reversals
autoformer_synthmulreversalspreds_168 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmulreversalstrue_168 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulreversalsmetrics_168 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 168-Hour Synthetic Multiplicative Data with Reversals
pyraformer_synthmulreversalspreds_168 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_168/preds.npy')
pyraformer_synthmulreversalstrue_168 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_168/trues.npy')


# Load Crossformer Results for 168-Hour Synthetic Multiplicative Data with Reversals
crossformer_synthmulreversalspreds_168 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl168_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmulreversalstrue_168 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl168_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulreversalsmetrics_168 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl168_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 168-Hour Synthetic Multiplicative Data with Reversals
fedformer_synthmulreversalspreds_168 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmulreversalstrue_168 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulreversalsmetrics_168 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 336-Hour Synthetic Multiplicative Data with Reversals
informer_synthmulreversalspreds_336 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmulreversalstrue_336 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulreversalsmetrics_336 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 336-Hour Synthetic Multiplicative Data
autoformer_synthmulreversalspreds_336 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmulreversalstrue_336 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulreversalsmetrics_336 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 336-Hour Synthetic Multiplicative Data with Reversals
pyraformer_synthmulreversalspreds_336 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_336/preds.npy')
pyraformer_synthmulreversalstrue_336 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_336/trues.npy')


# Load Crossformer Results for 336-Hour Synthetic Multiplicative Data with Reversals
crossformer_synthmulreversalspreds_336 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl336_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmulreversalstrue_336 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl336_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulreversalsmetrics_336 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl336_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 336-Hour Synthetic Multiplicative Data with Reversals
fedformer_synthmulreversalspreds_336 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmulreversalstrue_336 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulreversalsmetrics_336 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 720-Hour Synthetic Multiplicative Data with Reversals
informer_synthmulreversalspreds_720 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_synthmulreversalstrue_720 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_synthmulreversalsmetrics_720 = np.load('results/results_new/informerstack_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 720-Hour Synthetic Multiplicative Data with Reversals
autoformer_synthmulreversalspreds_720 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_synthmulreversalstrue_720 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_synthmulreversalsmetrics_720 = np.load('results/results_new/Autoformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Pyraformer Results for 720-Hour Synthetic Multiplicative Data with Reversals
pyraformer_synthmulreversalspreds_720 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_720/preds.npy')
pyraformer_synthmulreversalstrue_720 = np.load('results/results_new/Pyraformer_SYNTH_multiplicative_reversal_pred_len:_720/trues.npy')


# Load Crossformer Results for 720-Hour Synthetic Multiplicative Data with Reversals
crossformer_synthmulreversalspreds_720 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl720_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_synthmulreversalstrue_720 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl720_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_synthmulreversalsmetrics_720 = np.load('results/results_new/Crossformer_SYNTH_multiplicative_reversal_il96_pl720_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 720-Hour Synthetic Multiplicative Data with Reversals
fedformer_synthmulreversalspreds_720 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_synthmulreversalstrue_720 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_synthmulreversalsmetrics_720 = np.load('results/results_new/Fedformer_SYNTH_multiplicative_reversal_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# %%
mse_pyrasynthmulreversals_24 = np.array([MSE(pyraformer_synthmulreversalstrue_24[i, :, :], pyraformer_synthmulreversalspreds_24 [i, :, :]) for i in range(len(pyraformer_synthmulreversalstrue_24))])
mse_pyrasynthmulreversals_48 = np.array([MSE(pyraformer_synthmulreversalstrue_48[i, :, :], pyraformer_synthmulreversalspreds_48 [i, :, :]) for i in range(len(pyraformer_synthmulreversalstrue_48))])
mse_pyrasynthmulreversals_168 = np.array([MSE(pyraformer_synthmulreversalstrue_168[i, :, :], pyraformer_synthmulreversalspreds_168 [i, :, :]) for i in range(len(pyraformer_synthmulreversalstrue_168))])
mse_pyrasynthmulreversals_336 = np.array([MSE(pyraformer_synthmulreversalstrue_336[i, :, :], pyraformer_synthmulreversalspreds_336 [i, :, :]) for i in range(len(pyraformer_synthmulreversalstrue_336))])
mse_pyrasynthmulreversals_720 = np.array([MSE(pyraformer_synthmulreversalstrue_720[i, :, :], pyraformer_synthmulreversalspreds_720 [i, :, :]) for i in range(len(pyraformer_synthmulreversalstrue_720))])

# %%
mse_synthmulreversals_informer = [informer_synthmulreversalsmetrics_24[1], informer_synthmulreversalsmetrics_48[1], informer_synthmulreversalsmetrics_168[1], informer_synthmulreversalsmetrics_336[1], informer_synthmulreversalsmetrics_720[1]]
mse_synthmulreversals_autoformer = [autoformer_synthmulreversalsmetrics_24[1], autoformer_synthmulreversalsmetrics_48[1], autoformer_synthmulreversalsmetrics_168[1], autoformer_synthmulreversalsmetrics_336[1], autoformer_synthmulreversalsmetrics_720[1]]
mse_synthmulreversals_crossformer = [crossformer_synthmulreversalsmetrics_24[1], crossformer_synthmulreversalsmetrics_48[1], crossformer_synthmulreversalsmetrics_168[1], crossformer_synthmulreversalsmetrics_336[1], crossformer_synthmulreversalsmetrics_720[1]]
mse_synthmulreversals_fedformer = [fedformer_synthmulreversalsmetrics_24[1], fedformer_synthmulreversalsmetrics_48[1], fedformer_synthmulreversalsmetrics_168[1], fedformer_synthmulreversalsmetrics_336[1], fedformer_synthmulreversalsmetrics_720[1]]
mse_synthmulreversals_pyraformer = [np.mean(mse_pyrasynthmulreversals_24), np.mean(mse_pyrasynthmulreversals_48), np.mean(mse_pyrasynthmulreversals_168), np.mean(mse_pyrasynthmulreversals_336), np.mean(mse_pyrasynthmulreversals_720)]

# %%
windows = [24, 48, 168, 336, 720]
plt.figure(figsize=(12, 6))
plt.plot(windows, mse_synthmulreversals_informer, marker='o', label='Informer')
plt.plot(windows, mse_synthmulreversals_autoformer, marker='s', label='Autoformer')
plt.plot(windows, mse_synthmulreversals_crossformer , marker='^', label='Crossformer')
plt.plot(windows, mse_synthmulreversals_fedformer, marker='*', label='Fedformer')
#plt.plot(windows, mse_synthmulreversals_pyraformer, marker='x', label='Pyraformer')
plt.xlabel('Prediction Windows')
plt.ylabel('MSE')
plt.xticks(windows)
plt.title('Models Performances on Synthetic Data with Multiplicative Trend and Reversals')
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Wind Data

# %%
# Load Informer Results for 24-Hour Wind Data
informer_windpreds_24 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_windhtrue_24 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_windmetrics_24 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 24-Hour Wind Data
                                                       
autoformer_windpreds_24 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_windtrue_24 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_windmetrics_24 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Crossformer Results for 24-Hour Wind Data
                                                        
crossformer_windpreds_24 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_windtrue_24 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_windmetrics_24 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol24_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 24-Hour Wind Data
fedformer_windpreds_24 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_windtrue_24 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_windmetrics_24 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl24_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 48-Hour Wind Data
informer_windpreds_48 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_windtrue_48 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_windmetrics_48 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 48-Hour Wind Data
autoformer_windpreds_48 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_windtrue_48 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_windmetrics_48 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Crossformer Results for 48-Hour Wind Data
crossformer_windpreds_48 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_windtrue_48 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_windmetrics_48 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol48_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 48-Hour Wind Data
fedformer_windpreds_48 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_windtrue_48 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_windmetrics_48 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl48_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 168-Hour Wind Data
informer_windpreds_168 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_windtrue_168 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_windmetrics_168 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 168-Hour Wind Data
autoformer_windpreds_168 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_windtrue_168 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_windmetrics_168 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')


# Load Crossformer Results for 168-Hour Wind Data
crossformer_windhpreds_168 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_windtrue_168 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_windmetrics_168 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol168_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 168-Hour Wind Data
fedformer_windpreds_168 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_windtrue_168 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_windmetrics_168 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 336-Hour Wind Data
informer_windpreds_336 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_windtrue_336 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_windmetrics_336 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl336_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 336-Hour Wind Data
autoformer_windpreds_336 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_windtrue_336 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_windmetrics_336 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl168_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')

# Load Crossformer Results for 336-Hour Wind Data
crossformer_windpreds_336 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_windtrue_336 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_windmetrics_336 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol336_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 336-Hour Wind Data
fedformer_windpreds_336 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_windtrue_336 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_windmetrics_336 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl336_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# Load Informer Results for 720-Hour Wind Data
informer_windpreds_720 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/pred.npy')
informer_windtrue_720 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/true.npy')
informer_windmetrics_720 = np.load('results/results_new/informerstack_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_el[3, 2, 1]_dl2_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_1/metrics.npy')

# Load Autoformer Results for 720-Hour Wind Data
autoformer_windpreds_720 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/pred.npy')
autoformer_windtrue_720 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/true.npy')
autoformer_windmetrics_720 = np.load('results/results_new/Autoformer_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_Exp_1/metrics.npy')


# Load Crossformer Results for 720-Hour hWindetic Data
crossformer_windpreds_720 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/pred.npy')
crossformer_windtrue_720 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/true.npy')
crossformer_windmetrics_720 = np.load('results/results_new/Crossformer_DEWINDh_small_il96_ol720_sl6_win2_fa10_dm256_nh4_el3_itr1/metrics.npy')

# Load Fedformer Results for 720-Hour Wind Data
fedformer_windpreds_720 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/pred.npy')
fedformer_windtrue_720 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/true.npy')
fedformer_windmetrics_720 = np.load('results/results_new/Fedformer_DEWINDh_small_ftS_sl96_ll48_pl720_dm512_nh8_elNone_dl1_df2048_atNone_fc1_ebtimeF_dtTrue_mxNone_test_1/metrics.npy')

# %%
mse_wind_informer = [informer_windmetrics_24[1], informer_windmetrics_48[1], informer_windmetrics_168[1], informer_windmetrics_336[1], informer_windmetrics_720[1]]
mse_wind_autoformer = [autoformer_windmetrics_24[1], autoformer_windmetrics_48[1], autoformer_windmetrics_168[1], autoformer_windmetrics_336[1], autoformer_windmetrics_720[1]]
mse_wind_crossformer = [crossformer_windmetrics_24[1], crossformer_windmetrics_48[1], crossformer_windmetrics_168[1], crossformer_windmetrics_336[1], crossformer_windmetrics_720[1]]
mse_wind_fedformer = [fedformer_windmetrics_24[1], fedformer_windmetrics_48[1], fedformer_windmetrics_168[1], fedformer_windmetrics_336[1], fedformer_windmetrics_720[1]]

# %%
windows = [24, 48, 168, 336, 720]
plt.figure(figsize=(12, 6))
plt.plot(windows, mse_wind_informer, marker='o',  label='Informer')
plt.plot(windows, mse_wind_autoformer, marker='s', label='Autoformer')
plt.plot(windows, mse_wind_crossformer , marker='^', label='Crossformer')
plt.plot(windows, mse_wind_fedformer, marker='*',  label='Fedformer')
plt.xlabel('Prediction Windows')
plt.ylabel('MSE')
plt.xticks(windows)
plt.title('Models Performances on Wind Data ')
plt.legend()
plt.show()
plt.close()

# %%
### Wind Data MSE
print("Informer:\n")
print (mse_wind_informer)
print ("\n")
print("Autoformer:\n")
print (mse_wind_autoformer)
print ("\n")
print("Crossformer:\n")
print (mse_wind_crossformer)
print ("\n")
print("Fedformer:\n")
print (mse_wind_fedformer)
# Out:
# Informer:
#
# [0.14744301, 0.16313697, 0.20460685, 0.19674042, 0.19203492]
#
#
# Autoformer:
#
# [0.16973902, 0.17938697, 0.26637396, 0.26637396, 0.29382503]
#
#
# Crossformer:
#
# [0.13428518, 0.16478683, 0.19203016, 0.18873216, 0.19065166]
#
#
# Fedformer:
#
# [0.14251071, 0.16793232, 0.20434794, 0.2136833, 0.21459045]

# %%
### Synth Data MSE
print("Informer:\n")
print (mse_synth_informer)
print ("\n")
print("Autoformer:\n")
print (mse_synth_autoformer)
print ("\n")
print("Crossformer:\n")
print (mse_synth_crossformer)
print ("\n")
print("Fedformer:\n")
print (mse_synth_fedformer)
print ("\n")
print("Pyaformer:\n")
print (mse_synth_pyraformer)
# Out:
# Informer:
#
# [0.026107917, 0.034653045, 0.085835814, 0.10837621, 0.1087889]
#
#
# Autoformer:
#
# [0.110155106, 0.2409901, 0.7443057, 0.7443057, 0.91095436]
#
#
# Crossformer:
#
# [0.025039323, 0.03505309, 0.038142174, 0.029798893, 0.03305754]
#
#
# Fedformer:
#
# [0.06525204, 0.10054543, 0.32120854, 0.83328676, 0.583023]
#
#
# Pyaformer:
#
# [1.9625365, 2.5523114, 2.512528, 2.4885986, 2.228371]

# %%
### Synth Additive Data MSE
print("Informer:\n")
print (mse_synthadd_informer)
print ("\n")
print("Autoformer:\n")
print (mse_synthadd_autoformer)
print ("\n")
print("Crossformer:\n")
print (mse_synthadd_crossformer)
print ("\n")
print("Fedformer:\n")
print (mse_synthadd_fedformer)
print ("\n")
print("Pyaformer:\n")
print (mse_synthadd_pyraformer)
# Out:
# Informer:
#
# [0.1825204, 0.365345, 0.67418605, 1.1601923, 3.2019114]
#
#
# Autoformer:
#
# [0.017289385, 0.019241782, 0.10193131, 0.18343717, 0.15013796]
#
#
# Crossformer:
#
# [0.104372434, 0.20189671, 0.5383137, 1.1833626, 1.4263325]
#
#
# Fedformer:
#
# [0.012421983, 0.019944023, 0.069948085, 0.13483182, 0.12996231]
#
#
# Pyaformer:
#
# [2.0550802, 2.0070384, 2.4037216, 2.141919, 1.8867509]

# %%
### Synth Additive Reversals Data MSE
print("Informer:\n")
print (mse_synthaddreversal_informer)
print ("\n")
print("Autoformer:\n")
print (mse_synthaddreversal_autoformer)
print ("\n")
print("Crossformer:\n")
print (mse_synthaddreversal_crossformer)
print ("\n")
print("Fedformer:\n")
print (mse_synthaddreversal_fedformer)
# Out:
# Informer:
#
# [0.018012736, 0.031986415, 0.1440901, 0.32436076, 0.32005528]
#
#
# Autoformer:
#
# [0.05547475, 0.077946424, 0.27259436, 0.61690307, 0.69195163]
#
#
# Crossformer:
#
# [0.021311255, 0.037663765, 0.12212537, 0.30186367, 0.5469815]
#
#
# Fedformer:
#
# [0.045211427, 0.05541746, 0.14314777, 0.29863068, 0.41966835]

# %%
### Synth Multiplicative Data MSE
print("Informer:\n")
print (mse_synthmul_informer)
print ("\n")
print("Autoformer:\n")
print (mse_synthmul_autoformer)
print ("\n")
print("Crossformer:\n")
print (mse_synthmul_crossformer)
print ("\n")
print("Fedformer:\n")
print (mse_synthmul_fedformer)
print ("\n")
print("Pyaformer:\n")
print (mse_synthmul_pyraformer)
# Out:
# Informer:
#
# [0.6926553, 0.7542766, 1.7811744, 2.1003098, 6.351881]
#
#
# Autoformer:
#
# [0.2809368, 0.51652354, 0.73406386, 0.73406386, 1.5741451]
#
#
# Crossformer:
#
# [0.3401751, 0.46776658, 1.5330731, 1.6361986, 2.404357]
#
#
# Fedformer:
#
# [0.12513538, 0.17905474, 0.4361334, 0.8812577, 0.8493519]
#
#
# Pyaformer:
#
# [2.3705947, 2.3481877, 3.0745525, 2.3414485, 2.145338]

# %%
### Synth Multiplicative Reversals Data MSE
print("Informer:\n")
print (mse_synthmulreversals_informer)
print ("\n")
print("Autoformer:\n")
print (mse_synthmulreversals_autoformer)
print ("\n")
print("Crossformer:\n")
print (mse_synthmulreversals_crossformer)
print ("\n")
print("Fedformer:\n")
print (mse_synthmulreversals_fedformer)
print ("\n")
print("Pyaformer:\n")
print (mse_synthmulreversals_pyraformer)
# Out:
# Informer:
#
# [0.11776179, 0.15794155, 0.37248287, 0.5881099, 1.0453525]
#
#
# Autoformer:
#
# [0.16596125, 0.1903696, 0.6123178, 0.6123178, 1.7450969]
#
#
# Crossformer:
#
# [0.08941426, 0.19811969, 0.4996637, 0.8455656, 1.3339384]
#
#
# Fedformer:
#
# [0.13577239, 0.18140864, 0.42800578, 0.7323353, 1.4181877]
#
#
# Pyaformer:
#
# [3.4058316, 2.9240742, 3.122367, 3.019009, 2.754638]

# %% [markdown]
# ---

# %%
windows = [24, 48, 168, 336, 720]
fig , ax = plt.subplots(nrows= 3 , ncols = 1 , figsize = (16,16))

##Synthetic Data
ax[0].plot(windows, mse_synth_informer, marker='o', label='Informer')
ax[0].plot(windows, mse_synth_autoformer, marker='s', label='Autoformer')
ax[0].plot(windows, mse_synth_crossformer , marker='^', label='Crossformer')
ax[0].plot(windows, mse_synth_fedformer, marker='*', label='Fedformer')
ax[0].plot(windows, mse_synth_pyraformer, marker='x', label='Pyraformer')
ax[0].set_xlabel('Prediction Windows' , fontsize = 'small')
ax[0].set_xticks(windows)
ax[0].set_ylabel('MSE')
ax[0].set_title('Synthetic Data')
ax[0].legend(loc = 6 , fontsize = 'small')

##Synthetic Data with Additive Trend
ax[1].plot(windows, mse_synthadd_informer, marker='o', label='Informer')
ax[1].plot(windows, mse_synthadd_autoformer, marker='s', label='Autoformer')
ax[1].plot(windows, mse_synthadd_crossformer , marker='^', label='Crossformer')
ax[1].plot(windows, mse_synthadd_fedformer, marker='*', label='Fedformer')
ax[1].plot(windows, mse_synthadd_pyraformer, marker='x', label='Pyraformer')
ax[1].set_xlabel('Prediction Windows' , fontsize = 'small')
ax[1].set_ylabel('MSE')
ax[1].set_xticks(windows)
ax[1].set_title('Synthetic Data with Additive Trend')
ax[1].legend(loc = 2, fontsize = 'small')


ax[2].plot(windows, mse_synthaddreversal_informer, marker='o', label='Informer')
ax[2].plot(windows, mse_synthaddreversal_autoformer, marker='s', label='Autoformer')
ax[2].plot(windows, mse_synthaddreversal_crossformer , marker='^', label='Crossformer')
ax[2].plot(windows, mse_synthaddreversal_fedformer, marker='*', label='Fedformer')
#plt.plot(windows, mse_synthaddreversal_pyraformer, marker='x', label='Pyraformer')
ax[2].set_xlabel('Prediction Windows' , fontsize = 'small')
ax[2].set_ylabel('MSE')
ax[2].set_xticks([24, 48, 168, 336, 720])
ax[2].set_title('Synthetic Data with Additive Trend and Reversals')
ax[2].legend(fontsize = 'small')

plt.show()
plt.close()

# %%
windows = [24, 48, 168, 336, 720]
fig , ax = plt.subplots(nrows= 3 , ncols = 1 , figsize = (16,16))

##Synthetic Data
ax[0].plot(windows, mse_synth_informer, marker='o', label='Informer')
ax[0].plot(windows, mse_synth_autoformer, marker='s', label='Autoformer')
ax[0].plot(windows, mse_synth_crossformer , marker='^', label='Crossformer')
ax[0].plot(windows, mse_synth_fedformer, marker='*', label='Fedformer')
ax[0].plot(windows, mse_synth_pyraformer, marker='x', label='Pyraformer')
ax[0].set_xlabel('Prediction Windows' , fontsize = 'small')
ax[0].set_xticks(windows)
ax[0].set_ylabel('MSE')
ax[0].set_title('Synthetic Data')
ax[0].legend(loc = 6 , fontsize = 'small')

##Synthetic Data with Additive Trend
ax[1].plot(windows, mse_synthmul_informer, marker='o', label='Informer')
ax[1].plot(windows, mse_synthmul_autoformer, marker='s', label='Autoformer')
ax[1].plot(windows, mse_synthmul_crossformer , marker='^', label='Crossformer')
ax[1].plot(windows, mse_synthmul_fedformer, marker='*', label='Fedformer')
ax[1].plot(windows, mse_synthmul_pyraformer, marker='x', label='Pyraformer')
ax[1].set_xlabel('Prediction Windows' , fontsize = 'small')
ax[1].set_ylabel('MSE')
ax[1].set_xticks(windows)
ax[1].set_title('Synthetic Data with Multiplicative Trend')
ax[1].legend(loc = 2, fontsize = 'small')


ax[2].plot(windows, mse_synthmulreversals_informer, marker='o', label='Informer')
ax[2].plot(windows, mse_synthmulreversals_autoformer, marker='s', label='Autoformer')
ax[2].plot(windows, mse_synthmulreversals_crossformer , marker='^', label='Crossformer')
ax[2].plot(windows, mse_synthmulreversals_fedformer, marker='*', label='Fedformer')
#plt.plot(windows, mse_synthaddreversal_pyraformer, marker='x', label='Pyraformer')
ax[2].set_xlabel('Prediction Windows' , fontsize = 'small')
ax[2].set_ylabel('MSE')
ax[2].set_xticks([24, 48, 168, 336, 720])
ax[2].set_title('Synthetic Data with Multiplicativeve Trend and Reversals')
ax[2].legend(fontsize = 'small')

plt.show()
plt.close()
