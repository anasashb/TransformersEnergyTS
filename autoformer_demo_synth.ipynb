# %%
import sys
if not 'Autoformer' in sys.path:
    sys.path[0] += '/Autoformer'

# %%
import argparse
import os
import torch
from exp.exp_main import Exp_Main
import random
import numpy as np
from utils.tools import dotdict

fix_seed = 2021 
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)
# Out:
# 2023-11-28:23:23:35,373 INFO     [utils.py:147] Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2023-11-28:23:23:35,375 INFO     [utils.py:159] NumExpr defaulting to 8 threads.

# %% [markdown]
# ## Synthetic Data

# %% [markdown]
# ### First experiment - prediction length 24
# Set arguements for our model :<br>
# Data - Synthetic dataset 1<br>
# Model - Autoformer<br>
# Frequency - hourly<br>
# Features - univariate
# Encoder length - 96<br>
# Label length - 48<br>
# Prediction horizon - 24<br>

# %%
# args = parser.parse_args()
args = dotdict()
args.target = 'TARGET'
args.des = 'test'
args.dropout = 0.05
args.num_workers = 10
args.freq = 'h'
args.checkpoints = './checkpoints/'
args.bucket_size = 4
args.n_hashes = 4
args.is_trainging = True
args.root_path = './datasets'
args.data_path ='SYNTHh1.csv' 
args.model_id='Synth1_96_24'
args.model = 'Autoformer'
args.data = 'Synth1'
args.features = 'S' #univariate
args.seq_len = 96
args.label_len = 48
args.pred_len = 24
args.e_layers = 2
args.d_layers = 1
args.n_heads = 8
args.factor = 1
args.enc_in = 1
args.dec_in =1
args.c_out = 1
args.d_model = 512
args.des = 'Exp'
args.itr = 1
args.d_ff = 2048
args.moving_avg = 25
args.factor = 1
args.distil = True
args.output_attention = False
args.patience= 3
args.learning_rate = 0.0001
args.batch_size = 32 # batch size 32 as in the paper
args.embed = 'timeF'
args.activation = 'gelu'
args.use_amp = False
args.loss = 'mse'
args.train_epochs = 10 # epoch size is 10 as in the paper


# GPU 
args.gpu = 0
args.lradj = 'type1'
args.devices = '0,1,2,3'
args.use_multi_gpu = False
args.use_gpu = True if torch.cuda.is_available() else False

if args.use_gpu and args.use_multi_gpu:
     args.devices = args.devices.replace(' ', '')
     device_ids = args.devices.split(',')
     args.device_ids = [int(id_) for id_ in device_ids]
     args.gpu = args.device_ids[0]

print('Args in experiment:')
print(args)

Exp = Exp_Main
# Out:
# Args in experiment:
# {'target': 'TARGET', 'des': 'Exp', 'dropout': 0.05, 'num_workers': 10, 'freq': 'h', 'checkpoints': './checkpoints/', 'bucket_size': 4, 'n_hashes': 4, 'is_trainging': True, 'root_path': './datasets', 'data_path': 'SYNTHh1.csv', 'model_id': 'Synth1_96_24', 'model': 'Autoformer', 'data': 'Synth1', 'features': 'S', 'seq_len': 96, 'label_len': 48, 'pred_len': 24, 'e_layers': 2, 'd_layers': 1, 'n_heads': 8, 'factor': 1, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'd_model': 512, 'itr': 1, 'd_ff': 2048, 'moving_avg': 25, 'distil': True, 'output_attention': False, 'patience': 3, 'learning_rate': 0.0001, 'batch_size': 32, 'embed': 'timeF', 'activation': 'gelu', 'use_amp': False, 'loss': 'mse', 'train_epochs': 10, 'gpu': 0, 'lradj': 'type1', 'devices': '0,1,2,3', 'use_multi_gpu': False, 'use_gpu': True}

# %% [markdown]
# Train the model

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

for ii in range(args.itr):
    setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des, ii)

    exp_synth24 = Exp(args)  # set experiments
    print(1)
    print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
    exp_synth24.train(setting)
    print(2)
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    mae_synth24 , mse_synth24 , y_pred_synth24, y_true_synth24, first_batch_test_synth24 = exp_synth24.test(setting) 
    torch.cuda.empty_cache()
    print(3)
# Out:
# Use GPU: cuda:0
# 1
# >>>>>>>start training : Synth1_96_24_Autoformer_Synth1_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 12075
# val 1719
# test 3461
# 	iters: 100, epoch: 1 | loss: 0.2359104
# 	speed: 0.0445s/iter; left time: 163.2163s
# 	iters: 200, epoch: 1 | loss: 0.2100698
# 	speed: 0.0337s/iter; left time: 120.4107s
# 	iters: 300, epoch: 1 | loss: 0.1431544
# 	speed: 0.0340s/iter; left time: 118.0915s
# Epoch: 1 cost time: 13.88380765914917
# Epoch: 1, Steps: 377 | Train Loss: 0.2740040 Vali Loss: 0.1552836 Test Loss: 0.1552531
# Validation loss decreased (inf --> 0.155284).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.0541653
# 	speed: 0.1309s/iter; left time: 135.1059s
# 	iters: 200, epoch: 8 | loss: 0.0499474
# 	speed: 0.0335s/iter; left time: 31.1986s
# 	iters: 300, epoch: 8 | loss: 0.0478014
# 	speed: 0.0335s/iter; left time: 27.8824s
# Epoch: 8 cost time: 12.790041446685791
# Epoch: 8, Steps: 377 | Train Loss: 0.0486865 Vali Loss: 0.1019685 Test Loss: 0.0999172
# Validation loss decreased (0.106120 --> 0.101968).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.0402426
# 	speed: 0.1237s/iter; left time: 81.0384s
# 	iters: 200, epoch: 9 | loss: 0.0550407
# 	speed: 0.0332s/iter; left time: 18.4328s
# 	iters: 300, epoch: 9 | loss: 0.0612482
# 	speed: 0.0332s/iter; left time: 15.0907s
# Epoch: 9 cost time: 12.680357933044434
# Epoch: 9, Steps: 377 | Train Loss: 0.0485977 Vali Loss: 0.1010622 Test Loss: 0.0974073
# Validation loss decreased (0.101968 --> 0.101062).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.0456412
# 	speed: 0.1278s/iter; left time: 35.5298s
# 	iters: 200, epoch: 10 | loss: 0.0455453
# 	speed: 0.0324s/iter; left time: 5.7741s
# 	iters: 300, epoch: 10 | loss: 0.0457045
# 	speed: 0.0325s/iter; left time: 2.5320s
# Epoch: 10 cost time: 12.46204400062561
# Epoch: 10, Steps: 377 | Train Loss: 0.0481660 Vali Loss: 0.1005673 Test Loss: 0.0975510
# Validation loss decreased (0.101062 --> 0.100567).  Saving model ...
# Updating learning rate to 1.953125e-07
# 2
# >>>>>>>testing : Synth1_96_24_Autoformer_Synth1_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3461
# test shape: (3461, 24, 1) (3461, 24, 1)
# test shape: (3461, 24, 1) (3461, 24, 1)
# mse:0.09768936783075333, mae:0.23626993596553802
# 3

# %%
#Check the shape of the predictions and compare to real observations
print (y_pred_synth24.shape, y_true_synth24.shape)
# Out:
# (3461, 24, 1) (3461, 24, 1)

# %% [markdown]
# We have 3461 sequences of length 24, which is the prediction length we set.

# %%
#Shape of the the encoder and of the output in a single batch
print (first_batch_test_synth24['batch_x'].shape , first_batch_test_synth24['batch_y'].shape)
# Out:
# torch.Size([32, 96, 1]) (32, 24, 1)

# %%
#Shape of the marked data encoder and of the output in a single batch. 
#Each observation is assigned 4 marks - minute,hour,day of the week and day of the year.
print (first_batch_test_synth24['batch_x_mark'].shape , first_batch_test_synth24['batch_y_mark'].shape)
# Out:
# torch.Size([32, 96, 4]) torch.Size([32, 72, 4])

# %% [markdown]
# ### Second experiment - prediction length 168
# Set arguements for our model :<br>
# Data - Synthetic dataset 1<br>
# Model - Autoformer<br>
# Frequency - hourly<br>
# Features - univariate
# Encoder length - 96<br>
# Label length - 48<br>
# Prediction horizon - 168<br>

# %%
#All we have to do is change the prediction length arguement, all other arguements stay the same
args.pred_len = 168
args.model_id='Synth1_96_168'

# %%
for ii in range(args.itr):
    setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des, ii)

    exp_synth168 = Exp(args)  # set experiments
    print(1)
    print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
    exp_synth168.train(setting)
    print(2)
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    mae_synth168 , mse_synth168 , y_pred_synth168, y_true_synth168, first_batch_test_synth168 = exp_synth168.test(setting) 
    torch.cuda.empty_cache()
    print(3)
# Out:
# Use GPU: cuda:0
# 1
# >>>>>>>start training
    print(2)
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    mae_synth720 , mse_synth720 , y_pred_synth720, y_true_synth720, first_batch_test_synth720 = exp_synth720.test(setting) 
    torch.cuda.empty_cache()
    print(3)
# Out:
# Use GPU: cuda:0
# 1
# >>>>>>>start training : Synth1_96_24_Autoformer_Synth1_ftS_sl96_ll48_pl720_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 11379
# val 1023
# test 2765
# 	iters: 100, epoch: 1 | loss: 0.8391340
# 	speed: 0.1215s/iter; left time: 419.3440s
# 	iters: 200, epoch: 1 | loss: 0.9062921
# 	speed: 0.1144s/iter; left time: 383.3475s
# 	iters: 300, epoch: 1 | loss: 0.7131192
# 	speed: 0.1113s/iter; left time: 361.8280s
# Epoch: 1 cost time: 41.282639503479004
# Epoch: 1, Steps: 355 | Train Loss: 0.8701672 Vali Loss: 0.9200913 Test Loss: 1.1415159
# Validation loss decreased (inf --> 0.920091).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.5547497
# 	speed: 0.3073s/iter; left time: 951.5142s
# 	iters: 200, epoch: 2 | loss: 0.5021075
# 	speed: 0.1151s/iter; left time: 344.8169s
# 	iters: 300, epoch: 2 | loss: 0.3386720
# 	speed: 0.1173s/iter; left time: 339.7115s
# Epoch: 2 cost time: 41.583579540252686
# Epoch: 2, Steps: 355 | Train Loss: 0.5135001 Vali Loss: 0.8458613 Test Loss: 1.0116854
# Validation loss decreased (0.920091 --> 0.845861).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3453121
# 	speed: 0.3214s/iter; left time: 881.0431s
# 	iters: 200, epoch: 3 | loss: 0.3810774
# 	speed: 0.1119s/iter; left time: 295.4463s
# 	iters: 300, epoch: 3 | loss: 0.4632635
# 	speed: 0.1183s/iter; left time: 300.6074s
# Epoch: 3 cost time: 41.76781725883484
# Epoch: 3, Steps: 355 | Train Loss: 0.3898765 Vali Loss: 0.8490611 Test Loss: 0.9979600
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3289577
# 	speed: 0.3037s/iter; left time: 724.6933s
# 	iters: 200, epoch: 4 | loss: 0.3203935
# 	speed: 0.1155s/iter; left time: 264.0318s
# 	iters: 300, epoch: 4 | loss: 0.3261973
# 	speed: 0.1109s/iter; left time: 242.3556s
# Epoch: 4 cost time: 40.76060175895691
# Epoch: 4, Steps: 355 | Train Loss: 0.3792160 Vali Loss: 0.8693892 Test Loss: 1.0293325
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.3944921
# 	speed: 0.2907s/iter; left time: 590.4177s
# 	iters: 200, epoch: 5 | loss: 0.3649153
# 	speed: 0.1109s/iter; left time: 214.1527s
# 	iters: 300, epoch: 5 | loss: 0.3483295
# 	speed: 0.1151s/iter; left time: 210.6985s
# Epoch: 5 cost time: 40.421573877334595
# Epoch: 5, Steps: 355 | Train Loss: 0.3722800 Vali Loss: 0.8948020 Test Loss: 1.0436774
# EarlyStopping counter: 3 out of 3
# Early stopping
# 2
# >>>>>>>testing : Synth1_96_24_Autoformer_Synth1_ftS_sl96_ll48_pl720_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2765
# test shape: (2765, 720, 1) (2765, 720, 1)
# test shape: (2765, 720, 1) (2765, 720, 1)
# mse:1.0098739862442017, mae:0.8133849501609802
# 3

# %% [markdown]
# ## Wind data

# %% [markdown]
# Set arguements for our model :<br>
# Data - Wind dataset - Germany data<br>
# Model - Autoformer<br>
# Frequency - hourly<br>
# Features - univariate<br>
# Encoder length - 96<br>
# Label length - 48<br>
# Prediction horizon - 24<br>

# %%
args.data_path ='DEWINDh_small.csv' 
args.model_id='Windh1_96_24'
args.data = 'Windh1'
args.model = 'Autoformer'
args.freq = 'h'
args.features = 'S' #univariate
args.seq_len = 96
args.label_len = 48
args.pred_len = 24

# %%
for ii in range(args.itr):
    setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des, ii)

    ex
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.1160461
# 	speed: 0.1928s/iter; left time: 271.6848s
# 	iters: 200, epoch: 7 | loss: 0.1432014
# 	speed: 0.0521s/iter; left time: 68.1815s
# 	iters: 300, epoch: 7 | loss: 0.1164699
# 	speed: 0.0513s/iter; left time: 62.0795s
# Epoch: 7 cost time: 19.90695881843567
# Epoch: 7, Steps: 377 | Train Loss: 0.1221163 Vali Loss: 0.1665889 Test Loss: 0.1358864
# Validation loss decreased (0.170316 --> 0.166589).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.1177052
# 	speed: 0.1668s/iter; left time: 172.1031s
# 	iters: 200, epoch: 8 | loss: 0.1075221
# 	speed: 0.0343s/iter; left time: 31.9895s
# 	iters: 300, epoch: 8 | loss: 0.1238730
# 	speed: 0.0338s/iter; left time: 28.1623s
# Epoch: 8 cost time: 14.980851650238037
# Epoch: 8, Steps: 377 | Train Loss: 0.1209297 Vali Loss: 0.1686992 Test Loss: 0.1363175
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.1055276
# 	speed: 0.1828s/iter; left time: 119.7258s
# 	iters: 200, epoch: 9 | loss: 0.1239929
# 	speed: 0.0544s/iter; left time: 30.2022s
# 	iters: 300, epoch: 9 | loss: 0.1496626
# 	speed: 0.0539s/iter; left time: 24.5404s
# Epoch: 9 cost time: 21.148380041122437
# Epoch: 9, Steps: 377 | Train Loss: 0.1211020 Vali Loss: 0.1675436 Test Loss: 0.1361273
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.0938242
# 	speed: 0.1877s/iter; left time: 52.1823s
# 	iters: 200, epoch: 10 | loss: 0.1213382
# 	speed: 0.0590s/iter; left time: 10.5055s
# 	iters: 300, epoch: 10 | loss: 0.1441019
# 	speed: 0.0599s/iter; left time: 4.6715s
# Epoch: 10 cost time: 22.694470643997192
# Epoch: 10, Steps: 377 | Train Loss: 0.1208911 Vali Loss: 0.1661111 Test Loss: 0.1359445
# Validation loss decreased (0.166589 --> 0.166111).  Saving model ...
# Updating learning rate to 1.953125e-07
# 2
# >>>>>>>testing : Windh1_96_24_Autoformer_Windh1_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3461
# test shape: (3461, 24, 1) (3461, 24, 1)
# test shape: (3461, 24, 1) (3461, 24, 1)
# mse:0.1368371546268463, mae:0.227354034781456
# 3

# %% [markdown]
# ### Second experiment - prediction length 168
# Set arguements for our model :<br>
# Data - Wind dataset 1<br>
# Model - Autoformer<br>
# Frequency - hourly<br>
# Feature - univariate<br>
# Encoder length - 96<br>
# Label length - 48<br>
# Prediction horizon - 168<br>

# %%
args.model_id='Windh1_96_168'
args.pred_len = 168

# %%
for ii in range(args.itr):
    setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des, ii)

    exp_wind168 = Exp(args)  # set experiments
    print(1)
    print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
    exp_wind168.train(setting)
    print(2)
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    mae_wind168 , mse_wind168 , y_pred_wind168, y_true_wind168, first_batch_test_wind168 = exp_wind168.test(setting) 
    torch.cuda.empty_cache()
    print(3)
# Out:
# Use GPU: cuda:0
# 1
# >>>>>>>start training : Windh1_96_168_Autoformer_Windh1_ftS_sl96_ll48_pl168_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train
dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3317
# test shape: (3317, 168, 1) (3317, 168, 1)
# test shape: (3317, 168, 1) (3317, 168, 1)
# mse:0.2789977788925171, mae:0.36995598673820496
# 3

# %% [markdown]
# ### Third experiment - prediction length 720
# Set arguements for our model :<br>
# Data - Wind dataset 1<br>
# Model - Autoformer<br>
# Frequency - hourly<br>
# Feature - univariate<br>
# Encoder length - 96<br>
# Label length - 48<br>
# Prediction horizon - 720<br>

# %%
args.model_id='Windh1_96_720'
args.pred_len = 720

# %%
for ii in range(args.itr):
    setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
        args.model_id,
        args.model,
        args.data,
        args.features,
        args.seq_len,
        args.label_len,
        args.pred_len,
        args.d_model,
        args.n_heads,
        args.e_layers,
        args.d_layers,
        args.d_ff,
        args.factor,
        args.embed,
        args.distil,
        args.des, ii)

    exp_wind720 = Exp(args)  # set experiments
    print(1)
    print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
    exp_wind720.train(setting)
    print(2)
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    mae_wind720 , mse_wind720 , y_pred_wind720, y_true_wind720, first_batch_test_wind720 = exp_wind720.test(setting) 
    torch.cuda.empty_cache()
    print(3)
# Out:
# Use GPU: cuda:0
# 1
# >>>>>>>start training : Windh1_96_720_Autoformer_Windh1_ftS_sl96_ll48_pl720_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 11379
# val 1023
# test 2765
# 	iters: 100, epoch: 1 | loss: 0.3500079
# 	speed: 0.1957s/iter; left time: 675.4258s
# 	iters: 200, epoch: 1 | loss: 0.2912555
# 	speed: 0.1641s/iter; left time: 550.0364s
# 	iters: 300, epoch: 1 | loss: 0.3235041
# 	speed: 0.1771s/iter; left time: 575.8076s
# Epoch: 1 cost time: 60.85702729225159
# Epoch: 1, Steps: 355 | Train Loss: 0.3269537 Vali Loss: 0.3417270 Test Loss: 0.3934911
# Validation loss decreased (inf --> 0.341727).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2511774
# 	speed: 0.4219s/iter; left time: 1306.2298s
# 	iters: 200, epoch: 2 | loss: 0.2489091
# 	speed: 0.1804s/iter; left time: 540.4789s
# 	iters: 300, epoch: 2 | loss: 0.2387905
# 	speed: 0.1870s/iter; left time: 541.4119s
# Epoch: 2 cost time: 67.17349648475647
# Epoch: 2, Steps: 355 | Train Loss: 0.2527181 Vali Loss: 0.3207835 Test Loss: 0.5604863
# Validation loss decreased (0.341727 --> 0.320783).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2324595
# 	speed: 0.4649s/iter; left time: 1274.1777s
# 	iters: 200, epoch: 3 | loss: 0.2355143
# 	speed: 0.1816s/iter; left time: 479.5050s
# 	iters: 300, epoch: 3 | loss: 0.2283187
# 	speed: 0.1930s/iter; left time: 490.3978s
# Epoch: 3 cost time: 67.30262804031372
# Epoch: 3, Steps: 355 | Train Loss: 0.2310606 Vali Loss: 0.3180185 Test Loss: 0.6319754
# Validation loss decreased (0.320783 --> 0.318019).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2425275
# 	speed: 0.4473s/iter; left time: 1067.3378s
# 	iters: 200, epoch: 4 | loss: 0.2225284
# 	speed: 0.1446s/iter; left time: 330.5078s
# 	iters: 300, epoch: 4 | loss: 0.2142204
# 	speed: 0.1826s/iter; left time: 399.1108s
# Epoch: 4 cost time: 61.1696879863739
# Epoch: 4, Steps: 355 | Train Loss: 0.2225313 Vali Loss: 0.3184312 Test Loss: 0.6695099
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.2261557
# 	speed: 0.4602s/iter; left time: 934.7008s
# 	iters: 200, epoch: 5 | loss: 0.2208623
# 	speed: 0.1862s/iter; left time: 359.5567s
# 	iters: 300, epoch: 5 | loss: 0.2167841
# 	speed: 0.1912s/iter; left time: 350.1075s
# Epoch: 5 cost time: 67.5140106678009
# Epoch: 5, Steps: 355 | Train Loss: 0.2176509 Vali Loss: 0.3017602 Test Loss: 0.6502705
# Validation loss decreased (0.318019 --> 0.301760).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.2232880
# 	speed: 0.4624s/iter; left time: 775.0272s
# 	iters: 200, epoch: 6 | loss: 0.2199063
# 	speed: 0.1891s/iter; left time: 298.0701s
# 	iters: 300, epoch: 6 | loss: 0.1949297
# 	speed: 0.1745s/iter; left time: 257.5133s
# Epoch: 6 cost time: 64.9193365573883
# Epoch: 6, Steps: 355 | Train Loss: 0.2152042 Vali Loss: 0.3065163 Test Loss: 0.6793484
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.2115556
# 	speed: 0.4053s/iter; left time: 535.3964s
# 	iters: 200, epoch: 7 | loss: 0.2476386
# 	speed: 0.1962s/iter; left time: 239.6140s
# 	iters: 300, epoch: 7 | loss: 0.2373975
# 	speed: 0.1988s/iter; left time: 222.8675s
# Epoch: 7 cost time: 66.43930864334106
# Epoch: 7, Steps: 355 | Train Loss: 0.2142399 Vali Loss: 0.3045880 Test Loss: 0.6739417
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.2205698
# 	speed: 0.4461s/iter; left time: 430.8954s
# 	iters: 200, epoch: 8 | loss: 0.2166111
# 	speed: 0.1906s/iter; left time: 165.0609s
# 	iters: 300, epoch: 8 | loss: 0.2233944
# 	speed: 0.1858s/iter; left time: 142.3057s
# Epoch: 8 cost time: 66.92311239242554
# Epoch: 8, Steps: 355 | Train Loss: 0.2136297 Vali Loss: 0.3009123 Test Loss: 0.6650839
# Validation loss decreased (0.301760 --> 0.300912).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.2069863
# 	speed: 0.4602s/iter; left time: 281.1691s
# 	iters: 200, epoch: 9 | loss: 0.2291223
# 	speed: 0.1736s/iter; left time: 88.7161s
# 	iters: 300, epoch: 9 | loss: 0.1992643
# 	speed: 0.1375s/iter; left time: 56.5073s
# Epoch: 9 cost time: 58.93810677528381
# Epoch: 9, Steps: 355 | Train Loss: 0.2133811 Vali Loss: 0.3028817 Test Loss: 0.6738569
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.2083903
# 	speed: 0.4501s/iter; left time: 115.2287s
# 	iters: 200, epoch: 10 | loss: 0.2272068
# 	speed: 0.1795s/iter; left time: 28.0071s
# 	iters: 300, epoch: 10 | loss: 0.2364431
# 	speed: 0.1897s/iter; left time: 10.6220s
# Epoch: 10 cost time: 67.27152442932129
# Epoch: 10, Steps: 355 | Train Loss: 0.2132387 Vali Loss: 0.2998648 Test Loss: 0.6601291
# Validation loss decreased (0.300912 --> 0.299865).  Saving model ...
# Updating learning rate to 1.953125e-07
# 2
# >>>>>>>testing : Windh1_96_720_Autoformer_Windh1_ftS_sl96_ll48_pl720_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2765
# test shape: (2765, 720, 1) (2765, 720, 1)
# test shape: (2765, 720, 1) (2765, 720, 1)
# mse:0.660054087638855, mae:0.6229987740516663
# 3

# %%
plt.figure(figsize = (16,8))
plt.plot(y_pred_wind720[0,:,0] , c = 'black' , label = 'Predictions')
plt.plot(y_true_wind720[0,:,0] , c = 'darkred' , label = 'True values')
plt.title('Wind data 720-window - first time window sequence predictions')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(18,8))
plt.plot(y_pred_wind720[-1,:,0] , c = 'black' , label = 'Predictions')
plt.plot(y_true_wind720[-1,:,0] , c = 'darkred' , label = 'True values')
plt.title('Wind data 720-window - last time window sequence predictions')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
